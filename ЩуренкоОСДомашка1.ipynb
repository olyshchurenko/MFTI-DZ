# %%
# Этап 1. Генерация данных
# Изучите набор данных, располагающийся в архиве blood_cells.
# Выполните "нарезку" изображений. Сохраните в отдельные папки изображения фона и изображения клеток.
# Реализуйте генератор данных снимков клеток крови. На выходе генератор предосталвяет два изображения: сгенерированное без шума, сгенерированное с шумом.
# Патчи для формирования фона:
# 1) патчи, вырезанные из исходного набора данных
# 2) искусственно сформированные патчи (равномерная заливка фона из диапазона допустимых значений)
# Фон изображения формируется из набора патчей.
# Патчи для клеток крови:
# 1) патчи, вырезанные из исходного набора данных
# 2) искусствено сгенерированные окружности с заливкой из допустимого набора данных
# для blending-задачи применять: https://learnopencv.com/seamless-cloning-using-opencv-python-cpp/
# Примеры генераторов и загрузчиков данных найдете в исходной папке.
##########
# Основные этапы генерации:
# 1. Выбор, формирование патчей, их препроцессинг. Формирование(комбинирование) фона из набора патчей. Постпроцессинг результирующего фона.
# 2. Выбор метоположения клекток, выбор/формирование клеток, совмещение клеток на фоновом изображении
# 3. Выбор типа шума. Зашумление изображения.
#
# Генератор возвращает два изображения: зашумленное (этап 3) и исходное (этап 2) изображения.
#
# Этап 2. Исследование качества работы алгоритмов шумоподавления на сформированном датасете.
# Виды шумов:
# 1) Шум Гаусса
# 2) постоянный шум
# Виды фильтров:
# 1) Медианный фильтр
# 2) фильтр гаусса
# 3) билатериальный фильтр
# 4) фильтр нелокальных средних с различными параметрами.
# 5.1) самостоятелная реализация алгоритма шумоподавления (CPU)
# 5.2) самостоятелная реализация алгоритма шумоподавления (GPU)
# Метрики:
# 1) MSE
# 2) SSIM
# 3) время работы
#

# %%
import os
import cv2
import numpy as np
from PIL import Image
from skimage.metrics import mean_squared_error, structural_similarity
import time

# загрузка
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder, filename))
        if img is not None:
            images.append(img)
    return images

# нарезка на патчи
def slice_image(image, mask, patch_size):
    patches = []
    for i in range(0, image.shape[0], patch_size):
        for j in range(0, image.shape[1], patch_size):
            patch = image[i:i+patch_size, j:j+patch_size]
            mask_patch = mask[i:i+patch_size, j:j+patch_size]
            if np.any(mask_patch):  # Если клетка
                patches.append((patch, 'cell'))
            else:  # Если в патче только фон
                patches.append((patch, 'background'))
    return patches

# шум Гаусса
def add_gaussian_noise(image, mean=0, sigma=25):
    row, col, ch = image.shape
    gauss = np.random.normal(mean, sigma, (row, col, ch))
    noisy = image + gauss
    return np.clip(noisy, 0, 255).astype(np.uint8)

# постоянный шум
def add_salt_pepper_noise(image, amount=0.05):
    noisy = np.copy(image)
    num_salt = np.ceil(amount * image.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(num_salt)) for i in image.shape]
    noisy[coords] = 255
    num_pepper = np.ceil(amount * image.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(num_pepper)) for i in image.shape]
    noisy[coords] = 0
    return noisy

# путь к папкам
original_train = load_images_from_folder('original_train1')
mask_train = load_images_from_folder('mask_train1')
original_test = load_images_from_folder('original_test')
mask_test = load_images_from_folder('mask_test')

patch_size = 64
train_patches = []
for img, mask in zip(original_train, mask_train):
    train_patches.extend(slice_image(img, mask, patch_size))

test_patches = []
for img, mask in zip(original_test, mask_test):
    test_patches.extend(slice_image(img, mask, patch_size))

def save_patches(patches, base_folder):
    cell_folder = os.path.join(base_folder, 'cells')
    background_folder = os.path.join(base_folder, 'background')
    os.makedirs(cell_folder, exist_ok=True)
    os.makedirs(background_folder, exist_ok=True)
    for i, (patch, label) in enumerate(patches):
        if label == 'cell':
            cv2.imwrite(os.path.join(cell_folder, f'patch_{i}.png'), patch)
        else:
            cv2.imwrite(os.path.join(background_folder, f'patch_{i}.png'), patch)

save_patches(train_patches, 'train_patches')
save_patches(test_patches, 'test_patches')

def data_generator(patches, noise_type='gaussian'):
    for patch, label in patches:
        if label == 'cell':
            noisy_patch = add_gaussian_noise(patch) if noise_type == 'gaussian' else add_salt_pepper_noise(patch)
            yield patch, noisy_patch

from skimage.metrics import structural_similarity

def apply_filters_and_evaluate(clean, noisy):
    start_time = time.time()
    gaussian_filtered = cv2.GaussianBlur(noisy, (5, 5), 0)
    median_filtered = cv2.medianBlur(noisy, 5)
    bilateral_filtered = cv2.bilateralFilter(noisy, 9, 75, 75)
    nlm_filtered = cv2.fastNlMeansDenoisingColored(noisy, None, 10, 10, 7, 21)

    # Проверка размера изображений
    min_size = min(clean.shape[0], clean.shape[1])
    if min_size < 7:
        raise ValueError("Изображение слишком маленькое")

    # Вычисление SSIM
    win_size = min(7, min_size)  # проуерка win_size
    ssim_gaussian = structural_similarity(clean, gaussian_filtered, win_size=win_size, channel_axis=2)
    ssim_median = structural_similarity(clean, median_filtered, win_size=win_size, channel_axis=2)
    ssim_bilateral = structural_similarity(clean, bilateral_filtered, win_size=win_size, channel_axis=2)
    ssim_nlm = structural_similarity(clean, nlm_filtered, win_size=win_size, channel_axis=2)

    # Вычисление MSE
    mse_gaussian = mean_squared_error(clean, gaussian_filtered)
    mse_median = mean_squared_error(clean, median_filtered)
    mse_bilateral = mean_squared_error(clean, bilateral_filtered)
    mse_nlm = mean_squared_error(clean, nlm_filtered)

    end_time = time.time()
    elapsed_time = end_time - start_time

    return {
        'gaussian': {'mse': mse_gaussian, 'ssim': ssim_gaussian},
        'median': {'mse': mse_median, 'ssim': ssim_median},
        'bilateral': {'mse': mse_bilateral, 'ssim': ssim_bilateral},
        'nlm': {'mse': mse_nlm, 'ssim': ssim_nlm},
        'time': elapsed_time
    }

# %%
import matplotlib.pyplot as plt

def show_image(image, title):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis('off')
    plt.show()

for clean, noisy in data_generator(train_patches):
    show_image(clean, 'Сгенерированное без  шума')
    show_image(noisy, 'с шумом')
    break

# %%
# Счетчик, чтобы вывести несколько первых изображений
count = 0

for clean, noisy in data_generator(test_patches):

    results = apply_filters_and_evaluate(clean, noisy)

    show_image(clean, 'чистое изображение')
    show_image(noisy, 'изображение с шумом')
    show_image(cv2.GaussianBlur(noisy, (5, 5), 0), 'фильтр Гаусса')
    show_image(cv2.medianBlur(noisy, 5), 'медианный фильтр')
    show_image(cv2.bilateralFilter(noisy, 9, 75, 75), 'билатеральный фильтр')
    show_image(cv2.fastNlMeansDenoisingColored(noisy, None, 10, 10, 7, 21), 'фильтр нелокальных средних')

    # Вывод
    for filter_name, metrics in results.items():
        if filter_name == 'time':
            print(f"Время выполнения: {metrics:.2f} секунд")
        else:
            print(f"{filter_name.capitalize()}:")
            print(f"  MSE: {metrics['mse']:.2f}")
            print(f"  SSIM: {metrics['ssim']:.2f}")

    count += 1

    # 3 примера выведем
    if count >= 3:
        break
# Out:
# Gaussian:
#   MSE: 49.92
#   SSIM: 0.70
# Median:
#   MSE: 47.03
#   SSIM: 0.68
# Bilateral:
#   MSE: 35.15
#   SSIM: 0.76
# Nlm:
#   MSE: 27.84
#   SSIM: 0.90
# Время выполнения: 0.04 секунд
# Gaussian:
#   MSE: 58.51
#   SSIM: 0.78
# Median:
#   MSE: 58.87
#   SSIM: 0.77
# Bilateral:
#   MSE: 70.21
#   SSIM: 0.77
# Nlm:
#   MSE: 392.02
#   SSIM: 0.43
# Время выполнения: 0.05 секунд
# Gaussian:
#   MSE: 61.73
#   SSIM: 0.81
# Median:
#   MSE: 67.71
#   SSIM: 0.80
# Bilateral:
#   MSE: 85.79
#   SSIM: 0.78
# Nlm:
#   MSE: 323.40
#   SSIM: 0.54
# Время выполнения: 0.05 секунд

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/folder/mask_test.zip
# Out:
# Archive:  /content/drive/MyDrive/folder/mask_test.zip
#    creating: mask_test/
#   inflating: mask_test/e02301ac-68f7-4daf-b2ba-254b917f1cca.png
#   inflating: mask_test/e11515b4-9527-4c23-a0ba-43719bacca0d.png
#   inflating: mask_test/e13f2327-fbf4-4d84-a8c1-09cb1e449c8c.png
#   inflating: mask_test/e16c0dab-780d-4035-872e-1bb91e49f9d2.png
#   inflating: mask_test/e1937e32-85d5-4cd8-bb4a-b9cf8ee7ceeb.png
#   inflating: mask_test/e234ce8b-4ec4-4d93-9068-d7854d77ddf4.png
#   inflating: mask_test/e26b88c6-5884-4b5c-94d7-ad780379c8ad.png
#   inflating: mask_test/e36cb882-c6d0-4467-812e-d18c169a9a47.png
#   inflating: mask_test/e3ade58d-086c-47fa-9120-76beacb45395.png
#   inflating: mask_test/e3c1442a-717f-41dd-bf97-81e1233ac9fa.png
#   inflating: mask_test/e3e9c2de-0a24-4c7e-8a69-3d3093d5bdab.png
#   inflating: mask_test/e3ea07d7-884a-412e-874a-40fd6b856736.png
#   inflating: mask_test/e40000b4-1b26-42ce-909d-4715e04f0a6e.png
#   inflating: mask_test/e474a20b-2769-48f1-a520-4f6ef5a0dbf5.png
#   inflating: mask_test/e4827c85-311a-4df1-89c2-99dad0c3558c.png
#   inflating: mask_test/e4eea7ea-8989-46a9-9c98-25a178146b28.png
#   inflating: mask_test/e5731221-814c-4894-a44e-e46b71460fa4.png
#   inflating: mask_test/e597f7ce-46c6-4dce-9063-50a2703fdd45.png
#   inflating: mask_test/e5fd5949-4cd0-4cb6-837a-02c26a5eb87a.png
#   inflating: mask_test/e61e6af2-7f8b-47b0-bbe7-acb2ed0299ab.png
#   inflating: mask_test/e63e1607-f344-43d6-a0d8-e10cf2e5054a.png
#   inflating: mask_test/e640ae51-cbf1-4a84-b7cf-d38b17f59c2f.png
#   inflating: mask_test/e683144c-0465-43a2-86b1-3cf52599d5e0.png
#   inflating: mask_test/e6a7743e-4040-40fa-b097-ca6874c469b7.png
#   inflating: mask_test/e6d7c5e1-43fc-4712-86d5-aa70252b978f.png
#   inflating: mask_test/e726dac6-f962-449c-acff-4dd56847b685.png
#   inflating: mask_test/e79bd81b-f878-4bee-9be2-d91a722c031e.png
#   inflating: mask_test/e8058bed-c362-4e1c-85dc-62f80f32938f.png
#   inflating: mask_test/e80bad38-66d0-473e-85dd-92142dba37e6.png
#   inflating: mask_test/e81bf478-27ff-458c-ac30-9e1f8480bc5c.png
#   inflating: mask_test/e871f52c-77a6-4813-80d4-95bd97985f1a.png
#   inflating: mask_test/e93e617e-ed36-43d9-bd1a-4ffd2fba64e9.png
#   inflating: mask_test/e94a811d-3145-4313-ba42-2d5ed283179f.png
#   inflating: mask_test/e98baeb2-aa58-4cce-8c61-66685dd2b239.png
#   inflating: mask_test/e98ea067-82b5-4a0d-87bf-b4bbdc10ddab.png
#   inflating: mask_test/e9916e11-9be6-4dec-9df6-2e7d1a8e1735.png
#   inflating: mask_test/e9e78ff8-831b-46e9-9785-3eee9acbfcd8.png
#   inflating: mask_test/ea6b012a-3425-4bfc-a61d-88563aa2a264.png
#   inflating: mask_test/eaf4b781-b3aa-41ce-8c5e-287979b4e15a.png
#   inflating: mask_test/eb0173a3-7e5e-4f53-8124-03d9d6317844.png
#   inflating: mask_test/eb5f4f2f-2275-4a80-84a5-78a1eaf4ce4d.png
#   inflating: mask_test/eb6e8684-b84e-483d-b835-f59286d2516b.png
#   inflating: mask_test/eb77e4a9-acb0-4d83-8055-2c5fcaa54b45.png
#   inflating: mask_test/eb86033f-4f1c-4e8c-ae84-e8e4c7e08626.png
#   inflating: mask_test/eba73bff-fbe1-436d-9a5f-0a61331a0ea2.png
#   inflating: mask_test/ebb53337-1d4f-4ab5-9b6d-83a66f48fe2e.png
#   inflating: mask_test/ebc4056e-d766-43cf-b6b4-5dac79d96e84.png
#   inflating: mask_test/ebfd9f67-138e-49f0-9cef-a0352069eedb.png
#   inflating: mask_test/ec301f62-1302-4407-96f9-fcfe45c150ae.png
#   inflating: mask_test/ec60ab26-3343-4c5f-9667-cdae999c7d86.png
#   inflating: mask_test/ecd68ba2-48af-4866-826a-7cd1c147c055.png
#   inflating: mask_test/ed0bee2f-05e0-4392-8357-19750cec577c.png
#   inflating: mask_test/ed0d8763-e734-4506-b61b-53fc32a8d8c9.png
#   inflating: mask_test/edcb4d77-a4d3-465d-9b59-eb3087766b1c.png
#   inflating: mask_test/edd09b2e-2673-4405-8ac0-e476e003e96a.png
#   inflating: mask_test/edd3862f-04e1-49cf-97dd-ca566d17e71a.png
#   inflating: mask_test/edea6ca9-3d52-4b4f-bec3-93799b1c26e3.png
#   inflating: mask_test/ee57e743-a876-4f69-9fe5-bf5d01b44689.png
#   inflating: mask_test/eeac81a5-9202-4965-b7de-35b12910cdf6.png
#   inflating: mask_test/eeb06e39-482b-443d-8cf6-b9b5c763df78.png
#   inflating: mask_test/eed298b3-35f2-4127-88ad-0c4a9062207b.png
#   inflating: mask_test/eef2ac0b-42de-4bc3-a3c3-d5fcd597fbe4.png
#   inflating: mask_test/ef1419e0-3a3a-458a-b3b2-7efddac50404.png
#   inflating: mask_test/ef1a9020-5e45-450d-a237-165114308592.png
#   inflating: mask_test/ef55f2ac-5a04-4986-99ab-0d2b5052ab3e.png
#   inflating: mask_test/ef815e3a-02a6-4cf8-9262-45bc74c50b00.png
#   inflating: mask_test/ef83ed4c-2724-4d5f-8abe-1a18d25cea35.png
#   inflating: mask_test/ef8fcfa4-8466-4186-8c69-f5f4904eb489.png
#   inflating: mask_test/efb85f8e-c780-4a19-b6ce-555a154b0d10.png
#   inflating: mask_test/effd6334-516f-4d48-9f3c-5272a99780fb.png
#   inflating: mask_test/f01f6659-2114-4801-9d28-1f411432a589.png
#   inflating: mask_test/f05ffdca-dc3a-47bd-a231-2a0d9bd1d50e.png
#   inflating: mask_test/f06ba705-5509-479b-8067-127ffb37c5b6.png
#   inflating: mask_test/f070a212-e4e2-4743-804c-80789a36f495.png
#   inflating: mask_test/f0713bee-2a71-4ced-b953-4041ea99496a.png
#   inflating: mask_test/f07174a5-f799-4286-ac43-5b0f5c5777ac.png
#   inflating: mask_test/f0804a5e-e7f5-4cf2-a5df-b65e66502bf1.png
#   inflating: mask_test/f08e873b-9617-42b3-9c7a-55d0e39c2663.png
#   inflating: mask_test/f09acb0c-b270-4e91-99f8-410adfa7f34a.png
#   inflating: mask_test/f0ee03d6-c57b-43a0-8812-359330bdb93a.png
#   inflating: mask_test/f0fe292d-85ae-4c3a-a676-037dde2594e6.png
#   inflating: mask_test/f11d05e4-538a-4024-8711-b08a4ce3c540.png
#   inflating: mask_test/f1872d08-f8a6-4b21-aa29-f56bbf607883.png
#   inflating: mask_test/f1cda808-69a9-4d10-ba0a-6607c98e362d.png
#   inflating: mask_test/f1de7c7e-e7d3-45ae-a66c-58538bf6cac1.png
#   inflating: mask_test/f1f9df6d-c4cb-4b42-9ca2-8fb47b1b0e91.png
#   inflating: mask_test/f1faab5f-3033-45ea-9673-8b816fea5ce8.png
#   inflating: mask_test/f20a4fcf-ea8e-4c14-883d-d26a9e08ce25.png
#   inflating: mask_test/f232eec3-02c0-43f9-bf32-3e60245397e2.png
#   inflating: mask_test/f234a2de-f3c8-4521-a306-8cfdf52dd597.png
#   inflating: mask_test/f23ae29e-1bda-4784-b10c-d736757d39b8.png
#   inflating: mask_test/f24c8fe0-a534-44cf-9995-b2b314d945ba.png
#   inflating: mask_test/f2574be3-81c6-4fc3-8a40-0230d1264f52.png
#   inflating: mask_test/f25a2ac8-cb6e-4e05-a0cd-cc00ac47718a.png
#   inflating: mask_test/f274b784-b995-4a7e-a2c2-6cc31c24c4b4.png
#   inflating: mask_test/f28e6d66-af71-40c1-b30c-da71d7230a3f.png
#   inflating: mask_test/f2a8a483-b254-43aa-817f-7d525adb8911.png
#   inflating: mask_test/f2b1ae99-8169-42ea-bdb4-3351175e4cb6.png
#   inflating: mask_test/f329e01b-fbd3-4fb5-9738-a7ff4c8622b8.png
#   inflating: mask_test/f32b21ae-5ca7-490b-bc40-6db9396d933c.png
#   inflating: mask_test/f39e2289-fedd-4d12-9e64-ffdafb89247e.png
#   inflating: mask_test/f3bd0fcc-647d-4ca0-8c43-a16bd6ea3878.png
#   inflating: mask_test/f3d84be2-8af0-4d62-9f72-23d3dc08cbbe.png
#   inflating: mask_test/f4722a74-35e7-42bd-8ef6-dfff04b9cd22.png
#   inflating: mask_test/f48bf825-13c4-42fc-8dd8-10cc4ae6b202.png
#   inflating: mask_test/f4a27dfd-4c52-459f-96b5-ee6b452a3395.png
#   inflating: mask_test/f4c00b8c-d675-4255-8277-ca65bd757f51.png
#   inflating: mask_test/f4c2b43f-a2e7-4746-8034-0b34aebba8ee.png
#   inflating: mask_test/f5419bc0-4415-41b6-b832-5326cfcc534b.png
#   inflating: mask_test/f5869ba8-6253-426b-93f3-82af59a86144.png
#   inflating: mask_test/f5c395f1-f94c-440d-8221-cc656e52c0b1.png
#   inflating: mask_test/f5c51193-8a27-4ef3-83ad-771395d63caf.png
#   inflating: mask_test/f5eb7c5e-bd77-4638-ba9f-58d42f87476b.png
#   inflating: mask_test/f62d4fb6-df7c-446c-94a8-d5aede0b1e0c.png
#   inflating: mask_test/f632981c-1330-4078-8a12-691beb2dab02.png
#   inflating: mask_test/f65a1633-9935-4984-a285-a60d30aa1707.png
#   inflating: mask_test/f68ae8e9-e760-4106-88e0-4bdef2785f06.png
#   inflating: mask_test/f6ab936d-924b-4038-aa47-71b07c26b4e2.png
#   inflating: mask_test/f6f8a69a-3fd2-4684-ac77-3e83ea0fb36d.png
#   inflating: mask_test/f7231477-f2c1-439a-9c8b-204de07686a4.png
#   inflating: mask_test/f77d7469-d083-4c2d-a4ea-5a9ff162e3e2.png
#   inflating: mask_test/f7a4334a-4332-4de8-b39b-22da907976f2.png
#   inflating: mask_test/f7cced00-9b41-45ec-9fdf-fb9e1a74da90.png
#   inflating: mask_test/f81806a8-5883-446c-be78-f0145b12dbdd.png
#   inflating: mask_test/f8242b97-b8d5-48b5-b808-0b0f75a5de97.png
#   inflating: mask_test/f8a8b148-60e4-4a5c-ae19-941b19ec0846.png
#   inflating: mask_test/f8b14fc4-dd6b-4ad0-a96d-c62845f48681.png
#   inflating: mask_test/f8b6a868-60e9-4569-ae69-638a0c39834d.png
#   inflating: mask_test/f8ebe0c8-a90d-4a64-9f6a-f9985e38c340.png
#   inflating: mask_test/f91670db-be74-474c-bd72-68120aed4756.png
#   inflating: mask_test/f939782b-f5a2-40a3-9c22-6c6d7e18edc3.png
#   inflating: mask_test/f97c7c87-5e27-45ea-9f93-3285d74091de.png
#   inflating: mask_test/fa1f9f89-cecb-4972-842c-d14c632f89a9.png
#   inflating: mask_test/fa4f8d1a-cb3a-4722-a566-6c7072f30606.png
#   inflating: mask_test/fac4b0e2-6b52-4c0e-b762-4fa65d552856.png
#   inflating: mask_test/faead1c7-bb2c-4adf-bfce-9ff36cd2cf6a.png
#   inflating: mask_test/fb05b297-180a-4171-b633-09d5616d7534.png
#   inflating: mask_test/fbb1b44c-d75a-4550-a6c0-0eb62b96bfce.png
#   inflating: mask_test/fbc1f360-4382-48bb-a32e-3f5f2f9dbe57.png
#   inflating: mask_test/fbcb2ef0-3c97-4d7a-8b96-0147c73f3941.png
#   inflating: mask_test/fc15659f-6264-4dd5-ab17-43d89fb297b9.png
#   inflating: mask_test/fc8df086-39e0-43f8-b0c7-2d23a349539b.png
#   inflating: mask_test/fcc2b245-f47f-447f-8527-275b0005677c.png
#   inflating: mask_test/fcdf6632-c03f-49a8-9fb3-42e87c99b9d0.png
#   inflating: mask_test/fd1302e2-3cd2-4a1a-9c13-00f810a9c41b.png
#   inflating: mask_test/fd1c4c7a-24bc-43f2-b84f-fee182207aee.png
#   inflating: mask_test/fde0fd54-49cc-42e1-90c6-6b612cd062d8.png
#   inflating: mask_test/fe00fa09-d3c8-485b-9d0f-3cce556c9edd.png
#   inflating: mask_test/fe0c5e48-f65e-488c-9c3c-1ea7c7835c0c.png
#   inflating: mask_test/fe1ee954-ba71-47b3-954a-d20ab940cd7b.png
#   inflating: mask_test/fe436c09-b680-4f4c-8faf-aa10a55a335b.png
#   inflating: mask_test/fe691faa-3bc7-475e-b558-aa8fe7b795bc.png
#   inflating: mask_test/fe851c88-692d-4199-87e0-d19d9c4eb591.png
#   inflating: mask_test/fed6ba05-36a5-45dc-a4e1-9baa7de2c622.png
#   inflating: mask_test/ff1b23d0-3cef-459b-b81f-39bfcdb6526f.png
#   inflating: mask_test/ff37dd9b-2e3c-444d-9d29-6db186cfa2fb.png
#   inflating: mask_test/ff3b9d4d-373c-48ef-a75a-d23e2c2ade87.png
#   inflating: mask_test/ffb7be9a-65df-4f0b-99ae-cfd34e81cd34.png
#   inflating: mask_test/ffd59802-46c6-4b58-80fe-e534e39781a7.png

# %%
# !unzip /content/drive/MyDrive/folder/mask_train1.zip
# Out:
# Archive:  /content/drive/MyDrive/folder/mask_train1.zip
#    creating: mask_train1/
#   inflating: mask_train1/592c941a-aa54-4971-b499-dc47356f80a3.png
#   inflating: mask_train1/5939f341-a886-4f63-ae87-2219d000a1d4.png
#   inflating: mask_train1/597bbff8-6592-41cf-8946-e59b0d1f289a.png
#   inflating: mask_train1/59daa25e-85d6-42f2-8f39-cc9f9d5d252e.png
#   inflating: mask_train1/59dc7da9-35d1-421e-a61b-1e9637bfbfa1.png
#   inflating: mask_train1/59f5699f-885f-4004-b783-a60060144e43.png
#   inflating: mask_train1/5a539312-6cfa-43e6-8d5d-db883f343ad9.png
#   inflating: mask_train1/5a631871-2fc7-4a68-9c39-f3b9a0bf4a04.png
#   inflating: mask_train1/5bf91ff9-80df-49c0-9c3e-599357d95530.png
#   inflating: mask_train1/5bfde411-aa51-45d0-8b67-a57c5f1e628b.png
#   inflating: mask_train1/5c037ffc-f515-48b3-b231-c110fbd2b8ca.png
#   inflating: mask_train1/5c399ab9-492c-4bfc-a452-83aba574a3bc.png
#   inflating: mask_train1/5c5b7965-1a44-44b8-aa43-660823e61821.png
#   inflating: mask_train1/5c68070c-3391-4db6-8c01-94175105dbea.png
#   inflating: mask_train1/5c99cd97-39f6-4809-9528-9d380cc16b16.png
#   inflating: mask_train1/5cac6ddf-c8c6-45de-bce0-a1db64b14fb5.png
#   inflating: mask_train1/5ccca8ee-abea-458a-a891-bedd31c3ddc3.png
#   inflating: mask_train1/5d1418d3-1559-4725-ad4a-9afb6eaecdfd.png
#   inflating: mask_train1/5dec0204-af81-44ef-a942-8a173669c123.png
#   inflating: mask_train1/5dec94a3-e3ca-4a58-9702-88e5a83ef612.png
#   inflating: mask_train1/5e042380-6ef2-496f-8231-0ca550fbfa71.png
#   inflating: mask_train1/5e17f8e6-fd8d-426c-b444-1515d14f04b7.png
#   inflating: mask_train1/5e2cea49-0823-49d1-83cf-8fd1559cdd93.png
#   inflating: mask_train1/5e4f7425-11e6-4f9e-be2d-5a27deb9d1b4.png
#   inflating: mask_train1/5e974892-0ebe-4037-8427-ea8616d6d3b8.png
#   inflating: mask_train1/5f17d2fb-22fa-4aa6-9dad-6a1d50c03815.png
#   inflating: mask_train1/5f2b32bd-fdca-4d6f-b13a-ee9f83626c8d.png
#   inflating: mask_train1/5f300fd1-7eec-41ac-bbd1-0f4a943c757c.png
#   inflating: mask_train1/5f491efd-a21c-4a80-aaba-70b8876238ac.png
#   inflating: mask_train1/5f66d20c-fbfe-44ec-a01b-8a09da24807e.png
#   inflating: mask_train1/5f742392-278d-461c-a848-08def2c28878.png
#   inflating: mask_train1/5f783f43-0090-4f8a-bd75-9562f4aa2dd5.png
#   inflating: mask_train1/5ff7c0c8-d208-4e7d-958d-ca3c2260ff39.png
#   inflating: mask_train1/6013bff0-dc4b-4bde-9409-0f6139c3495c.png
#   inflating: mask_train1/6040cf0d-9dd6-4798-9406-1afbbcd24d4c.png
#   inflating: mask_train1/612bdd3c-da43-4321-a76b-c73c614928d1.png
#   inflating: mask_train1/61cd8c7d-394d-42d3-9ed4-e09559110bed.png
#   inflating: mask_train1/61dfc937-a428-44b4-94fb-d682bdb8dff0.png
#   inflating: mask_train1/6231d81d-9e84-4a5a-8cb8-47c6a37a0176.png
#   inflating: mask_train1/6274fe0d-0d71-40be-b61b-f0bd5b5df1e2.png
#   inflating: mask_train1/627d6331-7bb9-4d1a-b20d-e6541af4d0f9.png
#   inflating: mask_train1/6303f964-98ef-47c6-bb2d-283aa393f918.png
#   inflating: mask_train1/6315a55b-fed1-4355-88fa-8594538acf18.png
#   inflating: mask_train1/6347dd6a-cfdf-4cb5-bc50-cff5403cfecb.png
#   inflating: mask_train1/63d36d2c-43a9-49ac-9504-028b4968c860.png
#   inflating: mask_train1/63ed5931-d93e-4f9b-a6f3-152713cb560e.png
#   inflating: mask_train1/640c4a52-3742-4f57-aee3-9e3dc0887622.png
#   inflating: mask_train1/645cd195-af50-409f-8da9-6e7c7f18ea09.png
#   inflating: mask_train1/64a678d4-9048-4491-90c7-1924f38be19a.png
#   inflating: mask_train1/64b0e49a-0e48-447d-8872-c1dd255e7a21.png

# %%
# !unzip /content/drive/MyDrive/folder/original_test.zip
# Out:
# Archive:  /content/drive/MyDrive/folder/original_test.zip
#    creating: original_test/
#   inflating: original_test/e02301ac-68f7-4daf-b2ba-254b917f1cca.jpg
#   inflating: original_test/e11515b4-9527-4c23-a0ba-43719bacca0d.png
#   inflating: original_test/e13f2327-fbf4-4d84-a8c1-09cb1e449c8c.png
#   inflating: original_test/e16c0dab-780d-4035-872e-1bb91e49f9d2.png
#   inflating: original_test/e1937e32-85d5-4cd8-bb4a-b9cf8ee7ceeb.png
#   inflating: original_test/e234ce8b-4ec4-4d93-9068-d7854d77ddf4.png
#   inflating: original_test/e26b88c6-5884-4b5c-94d7-ad780379c8ad.jpg
#   inflating: original_test/e36cb882-c6d0-4467-812e-d18c169a9a47.png
#   inflating: original_test/e3ade58d-086c-47fa-9120-76beacb45395.png
#   inflating: original_test/e3c1442a-717f-41dd-bf97-81e1233ac9fa.png
#   inflating: original_test/e3e9c2de-0a24-4c7e-8a69-3d3093d5bdab.png
#   inflating: original_test/e3ea07d7-884a-412e-874a-40fd6b856736.png
#   inflating: original_test/e40000b4-1b26-42ce-909d-4715e04f0a6e.png
#   inflating: original_test/e474a20b-2769-48f1-a520-4f6ef5a0dbf5.png
#   inflating: original_test/e4827c85-311a-4df1-89c2-99dad0c3558c.png
#   inflating: original_test/e4eea7ea-8989-46a9-9c98-25a178146b28.png
#   inflating: original_test/e5731221-814c-4894-a44e-e46b71460fa4.png
#   inflating: original_test/e597f7ce-46c6-4dce-9063-50a2703fdd45.png
#   inflating: original_test/e5fd5949-4cd0-4cb6-837a-02c26a5eb87a.png
#   inflating: original_test/e61e6af2-7f8b-47b0-bbe7-acb2ed0299ab.png
#   inflating: original_test/e63e1607-f344-43d6-a0d8-e10cf2e5054a.png
#   inflating: original_test/e640ae51-cbf1-4a84-b7cf-d38b17f59c2f.png
#   inflating: original_test/e683144c-0465-43a2-86b1-3cf52599d5e0.png
#   inflating: original_test/e6a7743e-4040-40fa-b097-ca6874c469b7.jpg
#   inflating: original_test/e6d7c5e1-43fc-4712-86d5-aa70252b978f.png
#   inflating: original_test/e726dac6-f962-449c-acff-4dd56847b685.png
#   inflating: original_test/e79bd81b-f878-4bee-9be2-d91a722c031e.png
#   inflating: original_test/e8058bed-c362-4e1c-85dc-62f80f32938f.png
#   inflating: original_test/e80bad38-66d0-473e-85dd-92142dba37e6.png
#   inflating: original_test/e81bf478-27ff-458c-ac30-9e1f8480bc5c.png
#   inflating: original_test/e871f52c-77a6-4813-80d4-95bd97985f1a.png
#   inflating: original_test/e93e617e-ed36-43d9-bd1a-4ffd2fba64e9.jpg
#   inflating: original_test/e94a811d-3145-4313-ba42-2d5ed283179f.png
#   inflating: original_test/e98baeb2-aa58-4cce-8c61-66685dd2b239.png
#   inflating: original_test/e98ea067-82b5-4a0d-87bf-b4bbdc10ddab.png
#   inflating: original_test/e9916e11-9be6-4dec-9df6-2e7d1a8e1735.png
#   inflating: original_test/e9e78ff8-831b-46e9-9785-3eee9acbfcd8.png
#   inflating: original_test/ea6b012a-3425-4bfc-a61d-88563aa2a264.png
#   inflating: original_test/eaf4b781-b3aa-41ce-8c5e-287979b4e15a.png
#   inflating: original_test/eb0173a3-7e5e-4f53-8124-03d9d6317844.png
#   inflating: original_test/eb5f4f2f-2275-4a80-84a5-78a1eaf4ce4d.png
#   inflating: original_test/eb6e8684-b84e-483d-b835-f59286d2516b.png
#   inflating: original_test/eb77e4a9-acb0-4d83-8055-2c5fcaa54b45.png
#   inflating: original_test/eb86033f-4f1c-4e8c-ae84-e8e4c7e08626.png
#   inflating: original_test/eba73bff-fbe1-436d-9a5f-0a61331a0ea2.png
#   inflating: original_test/ebb53337-1d4f-4ab5-9b6d-83a66f48fe2e.png
#   inflating: original_test/ebc4056e-d766-43cf-b6b4-5dac79d96e84.jpg
#   inflating: original_test/ebfd9f67-138e-49f0-9cef-a0352069eedb.png
#   inflating: original_test/ec301f62-1302-4407-96f9-fcfe45c150ae.png
#   inflating: original_test/ec60ab26-3343-4c5f-9667-cdae999c7d86.png
#   inflating: original_test/ecd68ba2-48af-4866-826a-7cd1c147c055.png
#   inflating: original_test/ed0bee2f-05e0-4392-8357-19750cec577c.png
#   inflating: original_test/ed0d8763-e734-4506-b61b-53fc32a8d8c9.png
#   inflating: original_test/edcb4d77-a4d3-465d-9b59-eb3087766b1c.png
#   inflating: original_test/edd09b2e-2673-4405-8ac0-e476e003e96a.png
#   inflating: original_test/edd3862f-04e1-49cf-97dd-ca566d17e71a.png
#   inflating: original_test/edea6ca9-3d52-4b4f-bec3-93799b1c26e3.jpg
#   inflating: original_test/ee57e743-a876-4f69-9fe5-bf5d01b44689.png
#   inflating: original_test/eeac81a5-9202-4965-b7de-35b12910cdf6.png
#   inflating: original_test/eeb06e39-482b-443d-8cf6-b9b5c763df78.png
#   inflating: original_test/eed298b3-35f2-4127-88ad-0c4a9062207b.png
#   inflating: original_test/eef2ac0b-42de-4bc3-a3c3-d5fcd597fbe4.png
#   inflating: original_test/ef1419e0-3a3a-458a-b3b2-7efddac50404.png
#   inflating: original_test/ef1a9020-5e45-450d-a237-165114308592.png
#   inflating: original_test/ef55f2ac-5a04-4986-99ab-0d2b5052ab3e.jpg
#   inflating: original_test/ef815e3a-02a6-4cf8-9262-45bc74c50b00.png
#   inflating: original_test/ef83ed4c-2724-4d5f-8abe-1a18d25cea35.png
#   inflating: original_test/ef8fcfa4-8466-4186-8c69-f5f4904eb489.png
#   inflating: original_test/efb85f8e-c780-4a19-b6ce-555a154b0d10.jpg
#   inflating: original_test/effd6334-516f-4d48-9f3c-5272a99780fb.png
#   inflating: original_test/f01f6659-2114-4801-9d28-1f411432a589.png
#   inflating: original_test/f05ffdca-dc3a-47bd-a231-2a0d9bd1d50e.png
#   inflating: original_test/f06ba705-5509-479b-8067-127ffb37c5b6.png
#   inflating: original_test/f070a212-e4e2-4743-804c-80789a36f495.jpg
#   inflating: original_test/f0713bee-2a71-4ced-b953-4041ea99496a.png
#   inflating: original_test/f07174a5-f799-4286-ac43-5b0f5c5777ac.png
#   inflating: original_test/f0804a5e-e7f5-4cf2-a5df-b65e66502bf1.png
#   inflating: original_test/f08e873b-9617-42b3-9c7a-55d0e39c2663.jpg
#   inflating: original_test/f09acb0c-b270-4e91-99f8-410adfa7f34a.png
#   inflating: original_test/f0ee03d6-c57b-43a0-8812-359330bdb93a.jpg
#   inflating: original_test/f0fe292d-85ae-4c3a-a676-037dde2594e6.png
#   inflating: original_test/f11d05e4-538a-4024-8711-b08a4ce3c540.png
#   inflating: original_test/f1872d08-f8a6-4b21-aa29-f56bbf607883.png
#   inflating: original_test/f1cda808-69a9-4d10-ba0a-6607c98e362d.png
#   inflating: original_test/f1de7c7e-e7d3-45ae-a66c-58538bf6cac1.png
#   inflating: original_test/f1f9df6d-c4cb-4b42-9ca2-8fb47b1b0e91.png
#   inflating: original_test/f1faab5f-3033-45ea-9673-8b816fea5ce8.png
#   inflating: original_test/f20a4fcf-ea8e-4c14-883d-d26a9e08ce25.png
#   inflating: original_test/f232eec3-02c0-43f9-bf32-3e60245397e2.png
#   inflating: original_test/f234a2de-f3c8-4521-a306-8cfdf52dd597.png
#   inflating: original_test/f23ae29e-1bda-4784-b10c-d736757d39b8.png
#   inflating: original_test/f24c8fe0-a534-44cf-9995-b2b314d945ba.png
#   inflating: original_test/f2574be3-81c6-4fc3-8a40-0230d1264f52.png
#   inflating: original_test/f25a2ac8-cb6e-4e05-a0cd-cc00ac47718a.png
#   inflating: original_test/f274b784-b995-4a7e-a2c2-6cc31c24c4b4.png
#   inflating: original_test/f28e6d66-af71-40c1-b30c-da71d7230a3f.png
#   inflating: original_test/f2a8a483-b254-43aa-817f-7d525adb8911.png
#   inflating: original_test/f2b1ae99-8169-42ea-bdb4-3351175e4cb6.jpg
#   inflating: original_test/f329e01b-fbd3-4fb5-9738-a7ff4c8622b8.png
#   inflating: original_test/f32b21ae-5ca7-490b-bc40-6db9396d933c.png
#   inflating: original_test/f39e2289-fedd-4d12-9e64-ffdafb89247e.png
#   inflating: original_test/f3bd0fcc-647d-4ca0-8c43-a16bd6ea3878.png
#   inflating: original_test/f3d84be2-8af0-4d62-9f72-23d3dc08cbbe.png
#   inflating: original_test/f4722a74-35e7-42bd-8ef6-dfff04b9cd22.png
#   inflating: original_test/f48bf825-13c4-42fc-8dd8-10cc4ae6b202.png
#   inflating: original_test/f4a27dfd-4c52-459f-96b5-ee6b452a3395.png
#   inflating: original_test/f4c00b8c-d675-4255-8277-ca65bd757f51.png
#   inflating: original_test/f4c2b43f-a2e7-4746-8034-0b34aebba8ee.png
#   inflating: original_test/f5419bc0-4415-41b6-b832-5326cfcc534b.png
#   inflating: original_test/f5869ba8-6253-426b-93f3-82af59a86144.png
#   inflating: original_test/f5c395f1-f94c-440d-8221-cc656e52c0b1.png
#   inflating: original_test/f5c51193-8a27-4ef3-83ad-771395d63caf.png
#   inflating: original_test/f5eb7c5e-bd77-4638-ba9f-58d42f87476b.png
#   inflating: original_test/f62d4fb6-df7c-446c-94a8-d5aede0b1e0c.png
#   inflating: original_test/f632981c-1330-4078-8a12-691beb2dab02.png
#   inflating: original_test/f65a1633-9935-4984-a285-a60d30aa1707.png
#   inflating: original_test/f68ae8e9-e760-4106-88e0-4bdef2785f06.png
#   inflating: original_test/f6ab936d-924b-4038-aa47-71b07c26b4e2.png
#   inflating: original_test/f6f8a69a-3fd2-4684-ac77-3e83ea0fb36d.png
#   inflating: original_test/f7231477-f2c1-439a-9c8b-204de07686a4.png
#   inflating: original_test/f77d7469-d083-4c2d-a4ea-5a9ff162e3e2.png
#   inflating: original_test/f7a4334a-4332-4de8-b39b-22da907976f2.png
#   inflating: original_test/f7cced00-9b41-45ec-9fdf-fb9e1a74da90.png
#   inflating: original_test/f81806a8-5883-446c-be78-f0145b12dbdd.png
#   inflating: original_test/f8242b97-b8d5-48b5-b808-0b0f75a5de97.png
#   inflating: original_test/f8a8b148-60e4-4a5c-ae19-941b19ec0846.png
#   inflating: original_test/f8b14fc4-dd6b-4ad0-a96d-c62845f48681.png
#   inflating: original_test/f8b6a868-60e9-4569-ae69-638a0c39834d.png
#   inflating: original_test/f8ebe0c8-a90d-4a64-9f6a-f9985e38c340.jpg
#   inflating: original_test/f91670db-be74-474c-bd72-68120aed4756.png
#   inflating: original_test/f939782b-f5a2-40a3-9c22-6c6d7e18edc3.png
#   inflating: original_test/f97c7c87-5e27-45ea-9f93-3285d74091de.png
#   inflating: original_test/fa1f9f89-cecb-4972-842c-d14c632f89a9.png
#   inflating: original_test/fa4f8d1a-cb3a-4722-a566-6c7072f30606.png
#   inflating: original_test/fac4b0e2-6b52-4c0e-b762-4fa65d552856.png
#   inflating: original_test/faead1c7-bb2c-4adf-bfce-9ff36cd2cf6a.png
#   inflating: original_test/fb05b297-180a-4171-b633-09d5616d7534.png
#   inflating: original_test/fbb1b44c-d75a-4550-a6c0-0eb62b96bfce.png
#   inflating: original_test/fbc1f360-4382-48bb-a32e-3f5f2f9dbe57.png
#   inflating: original_test/fbcb2ef0-3c97-4d7a-8b96-0147c73f3941.png
#   inflating: original_test/fc15659f-6264-4dd5-ab17-43d89fb297b9.png
#   inflating: original_test/fc8df086-39e0-43f8-b0c7-2d23a349539b.png
#   inflating: original_test/fcc2b245-f47f-447f-8527-275b0005677c.png
#   inflating: original_test/fcdf6632-c03f-49a8-9fb3-42e87c99b9d0.png
#   inflating: original_test/fd1302e2-3cd2-4a1a-9c13-00f810a9c41b.png
#   inflating: original_test/fd1c4c7a-24bc-43f2-b84f-fee182207aee.png
#   inflating: original_test/fde0fd54-49cc-42e1-90c6-6b612cd062d8.png
#   inflating: original_test/fe00fa09-d3c8-485b-9d0f-3cce556c9edd.png
#   inflating: original_test/fe0c5e48-f65e-488c-9c3c-1ea7c7835c0c.png
#   inflating: original_test/fe1ee954-ba71-47b3-954a-d20ab940cd7b.png
#   inflating: original_test/fe436c09-b680-4f4c-8faf-aa10a55a335b.png
#   inflating: original_test/fe691faa-3bc7-475e-b558-aa8fe7b795bc.png
#   inflating: original_test/fe851c88-692d-4199-87e0-d19d9c4eb591.png
#   inflating: original_test/fed6ba05-36a5-45dc-a4e1-9baa7de2c622.png
#   inflating: original_test/ff1b23d0-3cef-459b-b81f-39bfcdb6526f.png
#   inflating: original_test/ff37dd9b-2e3c-444d-9d29-6db186cfa2fb.png
#   inflating: original_test/ff3b9d4d-373c-48ef-a75a-d23e2c2ade87.png
#   inflating: original_test/ffb7be9a-65df-4f0b-99ae-cfd34e81cd34.png
#   inflating: original_test/ffd59802-46c6-4b58-80fe-e534e39781a7.png

# %%
# !unzip /content/drive/MyDrive/folder/original_train1.zip
# Out:
# Archive:  /content/drive/MyDrive/folder/original_train1.zip
#    creating: original_train1/
#   inflating: original_train1/002f20ad-2ace-499c-9335-c9080bc3e6b5.png
#   inflating: original_train1/00a02700-2ea2-4590-9e15-ffc9160fd3de.png
#   inflating: original_train1/00c8364b-8c85-4502-bcfe-64736fe76815.png
#   inflating: original_train1/00d04a90-80e5-4bce-9511-1b64eabb7a47.png
#   inflating: original_train1/01b38a56-13eb-447b-89ee-fc21cb40dcc1.png
#   inflating: original_train1/01b99da8-b66b-464b-a7ee-1cadab8db18b.png
#   inflating: original_train1/02ea7aa8-c142-4a3d-939f-e77689741341.png
#   inflating: original_train1/0a747cb3-c720-4572-a661-ab5670a5c42e.png
#   inflating: original_train1/0a7bfa8a-ee52-4f7a-b9c5-2919ecfa93ef.png
#   inflating: original_train1/0ab56f9a-846d-49e2-a617-c6cc477fdfad.png
#   inflating: original_train1/0ac747cd-ff32-49bf-bc1a-3e9b7702ce9c.png
#   inflating: original_train1/0b04ec46-5119-4cda-8c35-c4e5b6f0eed0.png
#   inflating: original_train1/0b923ab7-ebff-4079-a4bb-af7da89f374e.png
#   inflating: original_train1/0ca25c88-457f-4f03-bbc1-98fb6663f1d1.png
#   inflating: original_train1/0ceb4539-5c4c-487d-9826-452a88b5d537.png
#   inflating: original_train1/0d095f3a-9243-472b-90b4-0ce8309e778c.png
#   inflating: original_train1/0d098413-6911-4535-b70a-3c3effd8cf49.png
#   inflating: original_train1/0d2aba33-6920-4001-bd54-59fe0bf9f50e.png
#   inflating: original_train1/0d3c2521-da55-4df5-bf06-56b3bd4fb2fc.png
#   inflating: original_train1/0d7bf56f-3b5a-40bd-971c-2ca33dd89b2c.png
#   inflating: original_train1/0da07970-3146-479c-8a07-f61ed32814a9.png
#   inflating: original_train1/0dcbf2c9-f959-4703-a72b-f6a81e66c2ea.png
#   inflating: original_train1/0dcca702-a4ef-4fb3-a940-9c0c140b21c7.png
#   inflating: original_train1/0ed416f9-7c20-4829-9016-559e4009568e.png
#   inflating: original_train1/0f0c949e-018a-4f3f-ab02-3704f49c7754.png
#   inflating: original_train1/0f26699f-a776-4424-b092-27da9a1d12e2.png
#   inflating: original_train1/0f2a6cda-afec-437b-8803-8d3176b072c1.png
#   inflating: original_train1/0f735cca-051c-4048-a1fa-cb36f389e12f.png
#   inflating: original_train1/0fa5b35d-6c44-4207-b6f8-d5b355086b5f.png
#   inflating: original_train1/0fcd1ebe-ee4a-40a0-b787-29cee18bfa1b.png
#   inflating: original_train1/1a27ebe9-93a1-4898-af69-f276057d4012.png
#   inflating: original_train1/1a332b2c-9d49-4ff2-810c-5633d2314527.png
#   inflating: original_train1/1a48cbc1-5423-47e5-8ca5-2ab4f83a05a5.png
#   inflating: original_train1/1b369bcf-ced4-4ae2-9196-2664bd2b1738.png
#   inflating: original_train1/1b7f47fc-26cd-4273-b848-88a7cbfd9f85.png
#   inflating: original_train1/1c406ce1-023b-47fc-a2cd-5ea2e255de65.png
#   inflating: original_train1/1c87b997-a8e6-48ca-bf40-19b9a7fd6a96.png
#   inflating: original_train1/1c90231b-2830-42d9-884e-7301edb16933.png
#   inflating: original_train1/1d4cdf2e-79a0-41e9-aabe-e437a190dfc4.png
#   inflating: original_train1/1d4f06e1-9c9b-487e-84cd-e7e50cc754da.png
#   inflating: original_train1/1d9d4dac-66f9-4c87-b714-d723d5b15fa9.png
#   inflating: original_train1/1dd3e6dd-343f-4cc9-b0ed-e4d27fb36f0a.png
#   inflating: original_train1/1e86933d-6a5a-4a3c-a0f2-ca22afd767b3.png
#   inflating: original_train1/1e978dfa-d339-4025-809d-09cee76728ed.png
#   inflating: original_train1/1ecb0405-a6e9-4485-819e-2fbbf2b718aa.png
#   inflating: original_train1/1f337b61-1b0d-4539-91f9-73d4a0798a4a.png
#   inflating: original_train1/1f8edb2a-40bc-4beb-aa6b-884d2473df0f.png
#   inflating: original_train1/1f8f08ea-b5b3-4f68-94d4-3cc071b7dce8.png
#   inflating: original_train1/1fdf99d1-a494-4174-bcd7-efbe457ab899.png
#   inflating: original_train1/1fe1e118-adb8-4b10-a41e-1e5814e8f067.png

# %%
# Удаление папки "my_folder" и всего её содержимого
# !rm -rf /content/test_patches
